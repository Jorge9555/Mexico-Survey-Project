# %%
import geopandas as gpd
import os
import matplotlib.pyplot as plt

# Direct path to the shapefile
shapefile_path = "/Volumes/EXMEM/New 176C Data/JaliscoDemographics(SHP+CSV)/MEX_Mun_2020.shp"

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(shapefile_path)

# %%
#gdf.plot("geometry", legend=True)
gdf.plot(color='red', edgecolor='black')
plt.title("Jalisco Municipalities")
# Out:
# Text(0.5, 1.0, 'Jalisco Municipalities')

# %%
gdf.head()
# Out:
#   cvegeo  nom_ent               nom_mun  pobtot  pobfem  pobmas  p_0a2  \
# 0  14001  Jalisco                Acatic   23175   11792   11383   1294
# 1  14002  Jalisco     Acatl n de Ju rez   25250   12006   13244   1195
# 2  14003  Jalisco  Ahualulco de Mercado   23630   11846   11784   1064
# 3  14004  Jalisco              Amacueca    5743    2967    2776    297
# 4  14005  Jalisco              Amatit n   16490    8306    8184    957
#
#    p_0a2_f  p_0a2_m  p_3ymas  ...  MUN_1             NOM_MUN_1  LOC  \
# 0      639      655    21881  ...      1                Acatic    0
# 1      597      598    24051  ...      2     Acatlán de Juárez    0
# 2      516      548    22542  ...      3  Ahualulco de Mercado    0
# 3      148      149     5446  ...      4              Amacueca    0
# 4      455      502    15532  ...      5              Amatitán    0
#
#                NOM_LOC  POBTOT_1  PE_INAC  PDESOCUP  P15YM_SE       SES  \
# ...
